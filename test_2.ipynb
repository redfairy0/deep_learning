# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
edges = [
    ('A1', 'B1', {'weigth':0.25}), ('A1', 'B2', {'weigth':0.45}), ('A1', 'B3', {'weigth':0.55}),
    ('A2', 'B1', {'weigth':0.15}), ('A2', 'B2', {'weigth':0.25}), ('A2', 'B3', {'weigth':0.35}),
    ('B1', 'C', {'weigth':0.75}), ('B2', 'C', {'weigth':0.15}), ('B3', 'C', {'weigth':0.25})]

G.add_nodes_from(['A1','A2','B1','B2','B3','C'])
positions = {'A1': [0, 1.5], 'A2': [0, 0.5], 'B1': [1, 2], 'B2': [1, 1], 'B3': [1, 0], 'C': [2, 1]}
weights = []
edges_labels = {}
for edge in edges:
    weights.append(edge[2]['weigth'])
    edges_labels[(edge[0], edge[1])] = str(edge[0])+str(edge[1])
G.add_edges_from(edges)

nx.draw(
    G, pos=positions, edge_color='black', width=weights, linewidths=1,
    node_size=500, node_color='pink', alpha=0.9,
    labels={node: node for node in G.nodes()}
)



nx.draw_networkx_edge_labels(
    G, pos=positions,
    edge_labels=edges_labels,
    verticalalignment='baseline',
    label_pos=0.3)
# Out:
# {('A1', 'B1'): Text(0.7, 1.8499999999999999, 'A1B1'),
#  ('A1', 'B2'): Text(0.7, 1.15, 'A1B2'),
#  ('A1', 'B3'): Text(0.7, 0.44999999999999996, 'A1B3'),
#  ('A2', 'B1'): Text(0.7, 1.5499999999999998, 'A2B1'),
#  ('A2', 'B2'): Text(0.7, 0.85, 'A2B2'),
#  ('A2', 'B3'): Text(0.7, 0.15, 'A2B3'),
#  ('B1', 'C'): Text(1.7, 1.2999999999999998, 'B1C'),
#  ('B2', 'C'): Text(1.7, 1.0, 'B2C'),
#  ('B3', 'C'): Text(1.7, 0.7, 'B3C')}

# %%
edges_labels
# Out:
# {('A1', 'B1'): 'A1B1',
#  ('A1', 'B2'): 'A1B2',
#  ('A1', 'B3'): 'A1B3',
#  ('A2', 'B1'): 'A2B1',
#  ('A2', 'B2'): 'A2B2',
#  ('A2', 'B3'): 'A2B3',
#  ('B1', 'C'): 'B1C',
#  ('B2', 'C'): 'B2C',
#  ('B3', 'C'): 'B3C'}

# %%
edges[0][2]['weigth']
# Out:
# 0.25

# %%
G.nodes['A1']['pos']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 G.nodes['A1']['pos']
#
# KeyError: 'pos'

# %%
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\k99rs\AppData\Local\Programs\Python\Python311\Lib\site-packages\networkx\drawing\nx_pylab.py:425, in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     424 try:
# --> 425     xy = np.asarray([pos[v] for v in nodelist])
#     426 except KeyError as err:
#
# File c:\Users\k99rs\AppData\Local\Programs\Python\Python311\Lib\site-packages\networkx\drawing\nx_pylab.py:425, in <listcomp>(.0)
#     424 try:
# --> 425     xy = np.asarray([pos[v] for v in nodelist])
#     426 except KeyError as err:
#
# KeyError: 'A1'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[56], line 2
#       1 subax2 = plt.subplot(122)
# ...

# %%
import numpy as np
from math import exp

# %%
np.array([[4,3,2],[1,3,4]])[0]
# Out:
# array([4, 3, 2])

# %%
np.sum(np.array([[4,3,2]])[0] * np.array([[1,2,3]]))
# Out:
# 16

# %%
def sigmoid(x):
    return 1 / (1 + exp(-x))

# %%
a = np.array([1,2,4])
a[0] = 0.1
a
# Out:
# array([0, 2, 4])

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
K33 = nx.complete_bipartite_graph(3, 3)

positions = {0: [-1, 1], 1: [0, 1], 2: [1, 1], 3: [-1, -1], 4: [0, -1], 5: [1, -1]}
ax = plt.figure().gca()
ax.set_axis_off()
options = {"node_size": 300, "node_color": "red"}
nx.draw_networkx(K33, positions, with_labels=False, **options)
plt.show()
